# %%
# !python entry_with_update.py --share
# Out:
# Update succeeded.
# [System ARGV] ['entry_with_update.py', '--share']
# Python 3.11.7 (tags/v3.11.7:fa7a6f2, Dec  4 2023, 19:24:49) [MSC v.1937 64 bit (AMD64)]
# Fooocus version: 1.0.0
# Error checking version for torchsde: No package metadata was found for torchsde
# Installing requirements
# Couldn't install requirements.
# Command: "C:\Users\theekshanas\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe" -m pip install -r "requirements_versions.txt" --prefer-binary
# Error code: 1
# stdout: Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...
#      ---------------------------------------- 0.0/59.2 kB ? eta -:--:--
#      ------------------- ------------------ 30.7/59.2 kB 660.6 kB/s eta 0:00:01
#      -------------------------------------- 59.2/59.2 kB 777.7 kB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/113.6 kB ? eta -:--:--
# ...

# %%
# !pip install pygit2==1.12.2
# %cd /content
# Out:
# Running cells with 'c:\Users\AAA\AppData\Local\Programs\Python\Python312\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/AAA/AppData/Local/Programs/Python/Python312/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %%
# !git clone https://github.com/theekshanamadumal/BTGen-image-generating.git
# %cd /content/BTGen-image-generating

# %%
# !python entry_with_update.py --share
