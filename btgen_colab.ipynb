# %%
# !pip install pygit2==1.12.2
# %cd /content
# !git clone https://github.com/oldhand7/gradio_work.git
# %cd /content/gradio_work
# !python entry_with_update.py --share
# Out:
# Running cells with 'c:\Users\AAA\AppData\Local\Programs\Python\Python312\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/AAA/AppData/Local/Programs/Python/Python312/python.exe -m pip install ipykernel -U --user --force-reinstall'
